# %%
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv("C:/Users/lokes/OneDrive/Desktop/tech_layoffs_2026_tracker.csv")

print(df)
# Out:
#                      company layoff_date  jobs_cut  pct_workforce_cut  \
# 0                     Amazon  2026-01-15     16000                2.7
# 1                      Block  2026-02-28      4000               40.0
# 2          Meta Reality Labs  2026-01-20      1500               10.0
# 3                  Atlassian  2026-03-14      1600               10.0
# 4                     Oracle  2026-02-01     30000               15.0
# 5                 Salesforce  2026-01-10      1000                1.4
# 6                   Autodesk  2026-01-25      1000                9.0
# 7                       eBay  2026-01-28       800                5.0
# 8                  Pinterest  2026-02-10       675                4.0
# 9                   Ericsson  2026-01-15      1600               12.0
# 10                      ASML  2026-01-20      1700                3.4
# 11                 ams OSRAM  2026-02-05      2000               12.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28 entries, 0 to 27
# Data columns (total 26 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   company                        28 non-null     object
#  1   layoff_date                    28 non-null     object
#  2   jobs_cut                       28 non-null     int64
#  3   pct_workforce_cut              28 non-null     float64
#  4   sector                         28 non-null     object
#  5   country                        28 non-null     object
#  6   hq_city                        28 non-null     object
#  7   ai_cited                       28 non-null     bool
#  8   reason_stated                  28 non-null     object
#  9   company_revenue_2025_bn        28 non-null     float64
#  10  pre_layoff_headcount           28 non-null     int64
#  11  stock_change_day_pct           28 non-null     float64
# ...

# %%
df.columns
# Out:
# Index(['company', 'layoff_date', 'jobs_cut', 'pct_workforce_cut', 'sector',
#        'country', 'hq_city', 'ai_cited', 'reason_stated',
#        'company_revenue_2025_bn', 'pre_layoff_headcount',
#        'stock_change_day_pct', 'simultaneous_ai_investment_bn',
#        'roles_most_affected', 'replacement_roles', 'ceo_quote', 'layoffs_2024',
#        'layoffs_2025', 'verified_source', 'month', 'quarter', 'region',
#        'layoff_size_category', 'stock_reaction', 'laid_off_vs_headcount_pct',
#        'data_as_of'],
#       dtype='object')

# %%
df.head()
# Out:
#              company layoff_date  jobs_cut  pct_workforce_cut  \
# 0             Amazon  2026-01-15     16000                2.7
# 1              Block  2026-02-28      4000               40.0
# 2  Meta Reality Labs  2026-01-20      1500               10.0
# 3          Atlassian  2026-03-14      1600               10.0
# 4             Oracle  2026-02-01     30000               15.0
#
#                 sector    country        hq_city  ai_cited  \
# 0     E-Commerce/Cloud        USA        Seattle     False
# 1              Fintech        USA  San Francisco      True
# 2      Social Media/VR        USA     Menlo Park      True
# 3  Enterprise Software  Australia         Sydney      True
# 4  Enterprise Software        USA         Austin      True
#
#                                    reason_stated  company_revenue_2025_bn  \
# 0       Reduce bureaucracy and management layers                    716.9
# 1  AI tools replace roles enabling smaller teams                     22.4
# ...

# %%
df.tail()
# Out:
#                      company layoff_date  jobs_cut  pct_workforce_cut  \
# 23                   Workday  2026-01-28      2200                8.5
# 24            Ergo Insurance  2026-03-01       200                2.0
# 25              Algoma Steel  2026-03-07      1000               20.0
# 26  Meta Platforms (Planned)  2026-03-13     16000               20.0
# 27              Algoma Steel  2026-03-23      1000               20.0
#
#              sector  country          hq_city  ai_cited  \
# 23  Enterprise SaaS      USA    Pleasanton CA      True
# 24        Insurance  Germany       Dusseldorf      True
# 25    Manufacturing   Canada  Sault Ste Marie     False
# 26  Social Media/AI      USA       Menlo Park      True
# 27    Manufacturing   Canada  Sault Ste Marie     False
#
#                                reason_stated  company_revenue_2025_bn  ...  \
# 23  AI investment and office space reduction                      8.5  ...
# ...

# %%
df['country'].value_counts()
# Out:
# country
# USA            17
# Australia       2
# Canada          2
# Sweden          1
# Netherlands     1
# Austria         1
# UK              1
# Spain           1
# India           1
# Germany         1
# Name: count, dtype: int64

# %%
df['sector'].value_counts()
# Out:
# sector
# Telecommunications          3
# Manufacturing               2
# Enterprise Software         2
# Semiconductors              2
# E-Commerce/Cloud            1
# EV Batteries                1
# Insurance                   1
# Enterprise SaaS             1
# Automotive Tech             1
# Interior Design Tech        1
# Cybersecurity               1
# AI Research                 1
# Retail Pharmacy             1
# Logistics Software          1
# Networking/Cybersecurity    1
# Fintech                     1
# Grocery Tech                1
# Social Media                1
# E-Commerce                  1
# Design Software             1
# CRM/SaaS                    1
# Social Media/VR             1
# Social Media/AI             1
# Name: count, dtype: int64

# %%
sns.scatterplot(data=df , x='layoffs_2024',y='layoffs_2025',hue='country')
sns.set_style('dark')

# %%
sns.scatterplot(data=df , x='layoffs_2024',y='layoffs_2025',hue='company')
sns.set_style('darkgrid')

# %%
sns.scatterplot(data=df , x='layoffs_2024',y='layoffs_2025',hue='country',palette='Dark2')
sns.set_style('ticks')
sns.despine(left=True)
sns.set_context('notebook')

# %%
sns.stripplot(data=df,x='jobs_cut',y='ai_cited',hue='month',dodge=True,jitter=True)
# Out:
# <Axes: xlabel='jobs_cut', ylabel='ai_cited'>

# %%
sns.swarmplot(data=df,x='company_revenue_2025_bn',y='stock_reaction',hue='country')
sns.set_context('talk')
sns.despine()

# %%
sns.histplot(data=df,x='pct_workforce_cut',hue='ai_cited',multiple='stack',kde=True)
sns.set_context('notebook')

# %%
sns.regplot(data=df,x='laid_off_vs_headcount_pct',y='pre_layoff_headcount',scatter=False)
# Out:
# <Axes: xlabel='laid_off_vs_headcount_pct', ylabel='pre_layoff_headcount'>

# %%
sns.regplot(data=df , x='layoffs_2024',y='layoffs_2025',color='green')
# Out:
# <Axes: xlabel='layoffs_2024', ylabel='layoffs_2025'>

# %%
sns.lineplot(data=df , x='layoffs_2024',y='layoffs_2025',hue='country',style='layoff_size_category')
# Out:
# <Axes: xlabel='layoffs_2024', ylabel='layoffs_2025'>

# %%
sns.jointplot(data=df,x='pct_workforce_cut',y='ai_cited',hue='sector')

# %%
sns.barplot(data=df, x="stock_change_day_pct", y="simultaneous_ai_investment_bn",hue='month',palette=['pink','skyblue'],estimator=np.mean)
# Out:
# C:\Users\lokes\AppData\Local\Temp\ipykernel_18608\1663797177.py:1: UserWarning:
# The palette list has fewer values (2) than needed (3) and will cycle, which may produce an uninterpretable plot.
#   sns.barplot(data=df, x="stock_change_day_pct", y="simultaneous_ai_investment_bn",hue='month',palette=['pink','skyblue'],estimator=np.mean)
# <Axes: xlabel='stock_change_day_pct', ylabel='simultaneous_ai_investment_bn'>

# %%
sns.countplot(data=df,x='hq_city',hue='country',palette='Set2')
# Out:
# <Axes: xlabel='hq_city', ylabel='count'>

# %%
sns.boxplot(data=df,x='region',y='layoffs_2025',hue='month')
# Out:
# <Axes: xlabel='region', ylabel='layoffs_2025'>

# %%
sns.violinplot(data=df,)
# Out:
# <Axes: >

# %%
sns.kdeplot(data=df,x='layoffs_2025',hue='region',fill=True)
# Out:
# <Axes: xlabel='layoffs_2025', ylabel='Density'>

# %%
df.head()
# Out:
#              company layoff_date  jobs_cut  pct_workforce_cut  \
# 0             Amazon  2026-01-15     16000                2.7
# 1              Block  2026-02-28      4000               40.0
# 2  Meta Reality Labs  2026-01-20      1500               10.0
# 3          Atlassian  2026-03-14      1600               10.0
# 4             Oracle  2026-02-01     30000               15.0
#
#                 sector    country        hq_city  ai_cited  \
# 0     E-Commerce/Cloud        USA        Seattle     False
# 1              Fintech        USA  San Francisco      True
# 2      Social Media/VR        USA     Menlo Park      True
# 3  Enterprise Software  Australia         Sydney      True
# 4  Enterprise Software        USA         Austin      True
#
#                                    reason_stated  company_revenue_2025_bn  \
# 0       Reduce bureaucracy and management layers                    716.9
# 1  AI tools replace roles enabling smaller teams                     22.4
# ...

# %%
columns=["jobs_cut","layoffs_2024","layoffs_2025","laid_off_vs_headcount_pct"]

# %%
 df[columns].corr()
# Out:
#                            jobs_cut  layoffs_2024  layoffs_2025  \
# jobs_cut                   1.000000      0.662275      0.687847
# layoffs_2024               0.662275      1.000000      0.807854
# layoffs_2025               0.687847      0.807854      1.000000
# laid_off_vs_headcount_pct  0.108620     -0.195352     -0.256521
#
#                            laid_off_vs_headcount_pct
# jobs_cut                                    0.108620
# layoffs_2024                               -0.195352
# layoffs_2025                               -0.256521
# laid_off_vs_headcount_pct                   1.000000

# %%
sns.heatmap(data=df[columns].corr(),annot=True, cmap="coolwarm")
# Out:
# <Axes: >

# %%
sns.rugplot(data=df,x="layoff_date",hue="region",palette="Set2")
# Out:
# <Axes: xlabel='layoff_date'>

# %%
sns.pairplot(data=df)

# %%
df.columns
# Out:
# Index(['company', 'layoff_date', 'jobs_cut', 'pct_workforce_cut', 'sector',
#        'country', 'hq_city', 'ai_cited', 'reason_stated',
#        'company_revenue_2025_bn', 'pre_layoff_headcount',
#        'stock_change_day_pct', 'simultaneous_ai_investment_bn',
#        'roles_most_affected', 'replacement_roles', 'ceo_quote', 'layoffs_2024',
#        'layoffs_2025', 'verified_source', 'month', 'quarter', 'region',
#        'layoff_size_category', 'stock_reaction', 'laid_off_vs_headcount_pct',
#        'data_as_of'],
#       dtype='object')
