# %%
import pandas as  pd
import numpy as np
import os

# %%
s = pd.Series([10,20,30,40])

print(s)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# dtype: int64

# %%
data = {
    "Name":["Lokesh","Ravi","Anu","Ritu"],
    "Age":[22,23,24,25]
}

df = pd.DataFrame(data)
print(df)
# Out:
#      Name  Age
# 0  Lokesh   22
# 1    Ravi   23
# 2     Anu   24
# 3    Ritu   25

# %%
df.head()      #First Five Rows
# Out:
#      Name  Age
# 0  Lokesh   22
# 1    Ravi   23
# 2     Anu   24
# 3    Ritu   25

# %%
df.tail()      #Last five rows
# Out:
#      Name  Age
# 0  Lokesh   22
# 1    Ravi   23
# 2     Anu   24
# 3    Ritu   25

# %%
 df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    4 non-null      object
#  1   Age     4 non-null      int64
# dtypes: int64(1), object(1)
# memory usage: 196.0+ bytes

# %%
df.describe()
# Out:
#              Age
# count   4.000000
# mean   23.500000
# std     1.290994
# min    22.000000
# 25%    22.750000
# 50%    23.500000
# 75%    24.250000
# max    25.000000

# %%
df['Name']
# Out:
# 0    Lokesh
# 1      Ravi
# 2       Anu
# 3      Ritu
# Name: Name, dtype: object

# %%
df[['Name','Age']]
# Out:
#      Name  Age
# 0  Lokesh   22
# 1    Ravi   23
# 2     Anu   24
# 3    Ritu   25

# %%
df['salary']=[200,250,300,350]

# %%
print(df)
# Out:
#   Full_Name  Age  salary
# 0    Lokesh   22     200
# 1      Ravi   23     250
# 2       Anu   24     300
# 3      Ritu   25     350

# %%
df['Age'].value_counts()
# Out:
# Age
# 22    1
# 23    1
# 24    1
# 25    1
# Name: count, dtype: int64

# %%
df['Age'].unique()
# Out:
# array([22, 23, 24, 25], dtype=int64)

# %%
df.rename(columns={'Name':'Full_Name'},inplace=True)

# %%
df["Age"] = df["Age"].apply(lambda x: x + 1)

# %%
print(df)
# Out:
#   Full_Name  Age  salary
# 0    Lokesh   23     200
# 1      Ravi   24     250
# 2       Anu   25     300
# 3      Ritu   26     350

# %%
df.iloc(0)

# %%
df.loc(0)

# %%
df[df['Age']>22]
# Out:
#    Name  Age
# 1  Ravi   23
# 2   Anu   24
# 3  Ritu   25

# %%
df["Salary"]=[20000,25000,45000,60000]

# %%
print(df)
# Out:
#      Name  Age  Salary
# 0  Lokesh   22   20000
# 1    Ravi   23   25000
# 2     Anu   24   45000
# 3    Ritu   25   60000

# %%
df.loc[0,'Age']=24

# %%
print(df)
# Out:
#      Name  Age  Salary
# 0  Lokesh   24   20000
# 1    Ravi   23   25000
# 2     Anu   24   45000
# 3    Ritu   25   60000

# %%
df.drop("Salary",axis=1,inplace=True)

# %%
print(df)
# Out:
#      Name  Age
# 0  Lokesh   24
# 1    Ravi   23
# 2     Anu   24
# 3    Ritu   25

# %%
df.sort_values(by='Age')
# Out:
#      Name  Age
# 1    Ravi   23
# 0  Lokesh   24
# 2     Anu   24
# 3    Ritu   25

# %%
df.isnull()
# Out:
#     Name    Age
# 0  False  False
# 1  False  False
# 2  False  False
# 3  False  False

# %%
df.dropna
# Out:
# <bound method DataFrame.dropna of      Name  Age
# 0  Lokesh   24
# 1    Ravi   23
# 2     Anu   24
# 3    Ritu   25>

# %%
df.fillna(0)
# Out:
#      Name  Age
# 0  Lokesh   24
# 1    Ravi   23
# 2     Anu   24
# 3    Ritu   25

# %%
df = pd.read_csv(r"C:\Users\lokes\OneDrive\Desktop\tech_layoffs_2026_tracker.csv")

# %%
print(df)
# Out:
#                      company layoff_date  jobs_cut  pct_workforce_cut  \
# 0                     Amazon  2026-01-15     16000                2.7
# 1                      Block  2026-02-28      4000               40.0
# 2          Meta Reality Labs  2026-01-20      1500               10.0
# 3                  Atlassian  2026-03-14      1600               10.0
# 4                     Oracle  2026-02-01     30000               15.0
# 5                 Salesforce  2026-01-10      1000                1.4
# 6                   Autodesk  2026-01-25      1000                9.0
# 7                       eBay  2026-01-28       800                5.0
# 8                  Pinterest  2026-02-10       675                4.0
# 9                   Ericsson  2026-01-15      1600               12.0
# 10                      ASML  2026-01-20      1700                3.4
# 11                 ams OSRAM  2026-02-05      2000               12.0
# ...

# %%
df.head()
# Out:
#              company layoff_date  jobs_cut  pct_workforce_cut  \
# 0             Amazon  2026-01-15     16000                2.7
# 1              Block  2026-02-28      4000               40.0
# 2  Meta Reality Labs  2026-01-20      1500               10.0
# 3          Atlassian  2026-03-14      1600               10.0
# 4             Oracle  2026-02-01     30000               15.0
#
#                 sector    country        hq_city  ai_cited  \
# 0     E-Commerce/Cloud        USA        Seattle     False
# 1              Fintech        USA  San Francisco      True
# 2      Social Media/VR        USA     Menlo Park      True
# 3  Enterprise Software  Australia         Sydney      True
# 4  Enterprise Software        USA         Austin      True
#
#                                    reason_stated  company_revenue_2025_bn  \
# 0       Reduce bureaucracy and management layers                    716.9
# 1  AI tools replace roles enabling smaller teams                     22.4
# ...

# %%
df.tail()
# Out:
#                      company layoff_date  jobs_cut  pct_workforce_cut  \
# 23                   Workday  2026-01-28      2200                8.5
# 24            Ergo Insurance  2026-03-01       200                2.0
# 25              Algoma Steel  2026-03-07      1000               20.0
# 26  Meta Platforms (Planned)  2026-03-13     16000               20.0
# 27              Algoma Steel  2026-03-23      1000               20.0
#
#              sector  country          hq_city  ai_cited  \
# 23  Enterprise SaaS      USA    Pleasanton CA      True
# 24        Insurance  Germany       Dusseldorf      True
# 25    Manufacturing   Canada  Sault Ste Marie     False
# 26  Social Media/AI      USA       Menlo Park      True
# 27    Manufacturing   Canada  Sault Ste Marie     False
#
#                                reason_stated  company_revenue_2025_bn  ...  \
# 23  AI investment and office space reduction                      8.5  ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28 entries, 0 to 27
# Data columns (total 26 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   company                        28 non-null     object
#  1   layoff_date                    28 non-null     object
#  2   jobs_cut                       28 non-null     int64
#  3   pct_workforce_cut              28 non-null     float64
#  4   sector                         28 non-null     object
#  5   country                        28 non-null     object
#  6   hq_city                        28 non-null     object
#  7   ai_cited                       28 non-null     bool
#  8   reason_stated                  28 non-null     object
#  9   company_revenue_2025_bn        28 non-null     float64
#  10  pre_layoff_headcount           28 non-null     int64
#  11  stock_change_day_pct           28 non-null     float64
# ...

# %%
df.describe()
# Out:
#            jobs_cut  pct_workforce_cut  company_revenue_2025_bn  \
# count     28.000000          28.000000                 28.00000
# mean    3612.357143          10.639286                 63.62500
# std     6546.591373          10.433505                139.44986
# min       50.000000           0.100000                  0.00000
# 25%      989.500000           2.525000                  3.50000
# 50%     1000.000000           7.750000                  9.40000
# 75%     2050.000000          15.000000                 53.90000
# max    30000.000000          40.000000                716.90000
#
#        pre_layoff_headcount  stock_change_day_pct  \
# count          2.800000e+01             28.000000
# mean           1.076631e+05              0.832143
# std            2.915339e+05              1.742721
# min            2.500000e+03             -2.100000
# 25%            8.750000e+03             -0.325000
# 50%            1.850000e+04              0.650000
# ...

# %%
df.shape
# Out:
# (28, 26)

# %%
df.columns
# Out:
# Index(['company', 'layoff_date', 'jobs_cut', 'pct_workforce_cut', 'sector',
#        'country', 'hq_city', 'ai_cited', 'reason_stated',
#        'company_revenue_2025_bn', 'pre_layoff_headcount',
#        'stock_change_day_pct', 'simultaneous_ai_investment_bn',
#        'roles_most_affected', 'replacement_roles', 'ceo_quote', 'layoffs_2024',
#        'layoffs_2025', 'verified_source', 'month', 'quarter', 'region',
#        'layoff_size_category', 'stock_reaction', 'laid_off_vs_headcount_pct',
#        'data_as_of'],
#       dtype='object')

# %%
df.dtypes
# Out:
# company                           object
# layoff_date                       object
# jobs_cut                           int64
# pct_workforce_cut                float64
# sector                            object
# country                           object
# hq_city                           object
# ai_cited                            bool
# reason_stated                     object
# company_revenue_2025_bn          float64
# pre_layoff_headcount               int64
# stock_change_day_pct             float64
# simultaneous_ai_investment_bn    float64
# roles_most_affected               object
# replacement_roles                 object
# ceo_quote                         object
# layoffs_2024                       int64
# layoffs_2025                       int64
# verified_source                   object
# month                             object
# quarter                           object
# region                            object
# layoff_size_category              object
# ...

# %%
df.memory_usage()
# Out:
# Index                            132
# company                          224
# layoff_date                      224
# jobs_cut                         224
# pct_workforce_cut                224
# sector                           224
# country                          224
# hq_city                          224
# ai_cited                          28
# reason_stated                    224
# company_revenue_2025_bn          224
# pre_layoff_headcount             224
# stock_change_day_pct             224
# simultaneous_ai_investment_bn    224
# roles_most_affected              224
# replacement_roles                224
# ceo_quote                        224
# layoffs_2024                     224
# layoffs_2025                     224
# verified_source                  224
# month                            224
# quarter                          224
# region                           224
# layoff_size_category             224
# stock_reaction                   224
# ...

# %%
df.isnull().sum()
# Out:
# company                          0
# layoff_date                      0
# jobs_cut                         0
# pct_workforce_cut                0
# sector                           0
# country                          0
# hq_city                          0
# ai_cited                         0
# reason_stated                    0
# company_revenue_2025_bn          0
# pre_layoff_headcount             0
# stock_change_day_pct             0
# simultaneous_ai_investment_bn    0
# roles_most_affected              0
# replacement_roles                0
# ceo_quote                        0
# layoffs_2024                     0
# layoffs_2025                     0
# verified_source                  0
# month                            0
# quarter                          0
# region                           0
# layoff_size_category             0
# stock_reaction                   0
# laid_off_vs_headcount_pct        0
# data_as_of                       0
# dtype: int64

# %%
df.sample()
# Out:
#        company layoff_date  jobs_cut  pct_workforce_cut              sector  \
# 18  Telefonica  2026-01-15      5000                5.0  Telecommunications
#
#    country hq_city  ai_cited                         reason_stated  \
# 18   Spain  Madrid     False  Cost restructuring with compensation
#
#     company_revenue_2025_bn  ...  layoffs_2024  layoffs_2025  verified_source  \
# 18                     44.5  ...             0          3000    FierceNetwork
#
#            month  quarter  region  layoff_size_category  stock_reaction  \
# 18  January 2026  Q1 2026  Europe         Large (2K-5K)        Positive
#
#    laid_off_vs_headcount_pct      data_as_of
# 18                       5.0  March 18, 2026
#
# [1 rows x 26 columns]

# %%
df['jobs_cut'].sum()
# Out:
# 101146

# %%
df['ai_cited'].value_counts()
# Out:
# ai_cited
# False    14
# True     14
# Name: count, dtype: int64

# %%
df.groupby('sector')['jobs_cut'].mean()
# Out:
# sector
# AI Research                    50.0
# Automotive Tech              1000.0
# CRM/SaaS                     1000.0
# Cybersecurity                 500.0
# Design Software              1000.0
# E-Commerce                    800.0
# E-Commerce/Cloud            16000.0
# EV Batteries                  958.0
# Enterprise SaaS              2200.0
# Enterprise Software         15800.0
# Fintech                      4000.0
# Grocery Tech                 1000.0
# Insurance                     200.0
# Interior Design Tech         1000.0
# Logistics Software           2000.0
# Manufacturing                1000.0
# Networking/Cybersecurity     6000.0
# Retail Pharmacy              1000.0
# Semiconductors               1850.0
# Social Media                  675.0
# Social Media/AI             16000.0
# Social Media/VR              1500.0
# Telecommunications           2321.0
# Name: jobs_cut, dtype: float64

# %%
df.groupby('country')['jobs_cut'].sum().sort_values(ascending=False)
# Out:
# country
# USA            83046
# Spain           5000
# Australia       3600
# Austria         2000
# Canada          2000
# Netherlands     1700
# Sweden          1600
# India           1000
# UK              1000
# Germany          200
# Name: jobs_cut, dtype: int64

# %%
df.groupby('stock_reaction')['jobs_cut'].mean()
# Out:
# stock_reaction
# Negative    1627.625000
# Neutral      416.666667
# Positive    5110.294118
# Name: jobs_cut, dtype: float64

# %%
df.groupby("ai_cited")["stock_change_day_pct"].mean()
# Out:
# ai_cited
# False   -0.242857
# True     1.907143
# Name: stock_change_day_pct, dtype: float64

# %%
df.sort_values(by="jobs_cut",ascending=False).head(5)
# Out:
#                      company layoff_date  jobs_cut  pct_workforce_cut  \
# 4                     Oracle  2026-02-01     30000               15.0
# 0                     Amazon  2026-01-15     16000                2.7
# 26  Meta Platforms (Planned)  2026-03-13     16000               20.0
# 14                     Cisco  2026-02-15      6000                7.0
# 18                Telefonica  2026-01-15      5000                5.0
#
#                       sector country     hq_city  ai_cited  \
# 4        Enterprise Software     USA      Austin      True
# 0           E-Commerce/Cloud     USA     Seattle     False
# 26           Social Media/AI     USA  Menlo Park      True
# 14  Networking/Cybersecurity     USA    San Jose     False
# 18        Telecommunications   Spain      Madrid     False
#
#                                reason_stated  company_revenue_2025_bn  ...  \
# 4          AI data centres replace human ops                     52.9  ...
# ...

# %%
df[["company_revenue_2025_bn", "jobs_cut"]].corr()
# Out:
#                          company_revenue_2025_bn  jobs_cut
# company_revenue_2025_bn                 1.000000  0.434519
# jobs_cut                                0.434519  1.000000
